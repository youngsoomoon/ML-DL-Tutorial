# %% [markdown]
# <a href="https://colab.research.google.com/github/youngsoomoon/ML-DL_Basic/blob/main/RandomForest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 1단계 Train, Test 데이터셋 분할하기
# scikit-learn 라이브러리 model_selection 클래스의 train_test_split 함수를 이용하여 train, test set 분할하기<br>
# * **test_size = 0.4** : train 60% , test 40%의 비율로 분할한다.
# * **shuffle = True** : 데이터를 무작위로 섞어서 분할한다
# * **random_state = 1004** : 재현가능하도록 난수의 초기값을 설정해주는 것이며, 아무숫자나 넣어주면 된다.

# %%
# 사용예시
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, shuffle=False, random_state=1004)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6fafc8d2c69f> in <module>()
#       1 # 사용예시
# ----> 2 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, shuffle=False, random_state=1004)
#
# NameError: name 'train_test_split' is not defined

# %% [markdown]
# ## 2단계, 랜덤포레스트 적용하기
# scikit-learn 라이브러리 ensemble 클래스의 RandomForestClassifier 함수를 사용한다.<br>
# RandomForestClassifier()의 파라미터 <br>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 사용예시
from sklearn.ensemble import RandomForestClassifier

rnd_clf = RandomForestClassifier(n_estimators=500, max_leaf_nodes=16, random_state=42)
rnd_clf.fit(X_train, y_train)

y_pred_rf = rnd_clf.predict(X_test)
